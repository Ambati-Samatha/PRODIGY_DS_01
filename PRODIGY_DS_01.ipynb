# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('Dataset1.csv')

# %%
df.head()
# Out:
#           Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0            Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1  LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2      Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3       Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4           Singh, Nan   1.307060e+09        0.0              0.0       0.0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  ...  \
# 0          1.0     1.0          3.0                     1.0    28.50  ...
# 1          1.0     1.0          3.0                     0.0    23.00  ...
# 2          1.0     1.0          3.0                     0.0    29.00  ...
# 3          1.0     1.0          3.0                     0.0    21.50  ...
# 4          1.0     1.0          3.0                     0.0    16.56  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               310 non-null    object
#  1   EmpID                       310 non-null    float64
#  2   MarriedID                   310 non-null    float64
#  3   MaritalStatusID             310 non-null    float64
#  4   GenderID                    310 non-null    float64
#  5   EmpStatusID                 310 non-null    float64
#  6   DeptID                      310 non-null    float64
#  7   PerfScoreID                 310 non-null    float64
#  8   FromDiversityJobFairID      310 non-null    float64
#  9   PayRate                     310 non-null    float64
#  10  Termd                       310 non-null    float64
#  11  PositionID                  310 non-null    float64
#  12  Position                    310 non-null    object
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count  3.100000e+02  310.000000       310.000000  310.000000   310.000000
# mean   1.199745e+09    0.396774         0.809677    0.429032     2.396774
# std    1.829600e+08    0.490019         0.944702    0.495738     1.795533
# min    6.020003e+08    0.000000         0.000000    0.000000     1.000000
# 25%    1.101024e+09    0.000000         0.000000    0.000000     1.000000
# 50%    1.203032e+09    0.000000         1.000000    0.000000     1.000000
# 75%    1.378814e+09    1.000000         1.000000    1.000000     5.000000
# max    1.988300e+09    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID     PayRate  \
# count  310.000000   310.000000              310.000000  310.000000
# mean     4.606452     2.983871                0.093548   31.284806
# std      1.082349     0.577124                0.291670   15.383615
# ...

# %%
# Convert 'DOB' column to datetime
df['DOB'] = pd.to_datetime(df['DOB'], errors='coerce')

# %%
# Calculate ages from birthdates
df['Age'] = (pd.to_datetime('today') - df['DOB']).dt.days // 365.25

# %%
# Group data by gender, employment status, and recruitment source
gender_employment_source_counts = df.groupby(['Sex', 'EmploymentStatus', 'RecruitmentSource']).size().unstack()

# %%
# Create a bar chart
fig, ax = plt.subplots(figsize=(10, 6))
gender_employment_source_counts.plot(kind='bar', stacked=True, ax=ax)

ax.set_xlabel('Gender and Employment Status')
ax.set_ylabel('Count')
ax.set_title('Distribution of Employment Status, Recruitment Source by Gender')
ax.legend(bbox_to_anchor=(1.05, 1))

plt.tight_layout()
plt.show()
